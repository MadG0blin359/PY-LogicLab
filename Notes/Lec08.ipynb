# %% [markdown]
# # CS4048 (Lec 08) Pandas III
#
# Notebook adapted from Data 100, UC Berkeley

# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Loading `babynames` Dataset for California

# %%
import urllib.request
import os.path
import zipfile

data_url = "https://www.ssa.gov/oact/babynames/state/namesbystate.zip"
local_filename = "/content/drive/MyDrive/Classroom/Data Science/namesbystate.zip"
if not os.path.exists(local_filename): # If the data exists don't download again
    with urllib.request.urlopen(data_url) as resp, open(local_filename, 'wb') as f:
        f.write(resp.read())

zf = zipfile.ZipFile(local_filename, 'r')

ca_name = 'CA.TXT'
field_names = ['State', 'Sex', 'Year', 'Name', 'Count']
with zf.open(ca_name) as fh:
    babynames = pd.read_csv(fh, header=None, names=field_names)

babynames.tail(10)
# Out:
#        State Sex  Year      Name  Count
# 420399    CA   M  2024    Zaxton      5
# 420400    CA   M  2024    Zaylin      5
# 420401    CA   M  2024  Zedekiah      5
# 420402    CA   M  2024     Zekai      5
# 420403    CA   M  2024      Zexi      5
# 420404    CA   M  2024      Ziad      5
# 420405    CA   M  2024      Ziah      5
# 420406    CA   M  2024    Zohaan      5
# 420407    CA   M  2024    Zubair      5
# 420408    CA   M  2024      Zuko      5

# %% [markdown]
# ## Grouping
#
# Group rows that share a common feature, then aggregate data across the group.
#
# In this example, we count the total number of babies born each year in California.

# %%
babynames.groupby("Year")

# %%
# Grouping by "Year" and aggregating the "Count" column
# to get the total number of babies born each year.
babies_by_year = babynames.groupby("Year")[["Count"]].agg("sum")
babies_by_year
# Out:
#        Count
# Year
# 1910    9163
# 1911    9983
# 1912   17946
# 1913   22094
# 1914   26925
# ...      ...
# 2020  363600
# 2021  363665
# 2022  362544
# 2023  344312
# 2024  344171
#
# [115 rows x 1 columns]

# %%
# Plotting baby counts per year
# Don't worry about the syntax here. We will cover visualization later in the course.
fig = px.line(babies_by_year, y="Count")
fig.update_layout(font_size=18,
                  autosize=False,
                  width=700,
                  height=400)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9cea52ec-253e-40ab-8860-8a14260c7b72" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9cea52ec-253e-40ab-8860-8a14260c7b72")) {                    Plotly.newPlot(                        "9cea52ec-253e-40ab-8860-8a14260c7b72",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[9163,9983,17946,22094,26925,35835,37501,39916,44692,45119,54142,58984,61002,67917,74449,73492,72910,74204,74263,72101,75294,71474,69521,66897,69786,71609,74935,83738,91628,93466,102629,114311,142044,159812,164360,171773,204944,232316,229045,233631,235568,250471,271674,287488,297104,304560,324180,340054,337694,345993,358506,364059,360485,361885,355381,336566,319439,318822,321027,333658,342399,310011,287227,275054,286945,290530,302555,315010,322254,343070,365981,382169,390580,394614,404982,425631,435997,453857,480663,512633,552697,549361,541120,524996,509348,494660,483319,468423,464323,460853,471694,466953,467773,477687,480940,484562,495056,497695,483459,460386,444727,437951,439530,432120,440879,431535,427294,411350,395859,387572,363600,363665,362544,344312,344171],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscal ...

# %% [markdown]
# ### Exercise
#
# Try to predict the results of the `groupby` operation shown. The answer is below the image.

# %% [markdown]
# <img src="images/groupby_mystery.png" alt="Image" width="600">

# %%
df = pd.DataFrame({
  'col1' : ['A', 'B', 'C', 'A', 'B', 'C', 'A', 'C', 'B'],
  'col2' : [3, 1, 4, 1, 5, 9, 2, 5, 6],
  'col3' : ['ak', 'tx', 'fl', 'hi', 'mi', 'ak', 'ca', 'sd', 'nc']
})
df
# Out:
#   col1  col2 col3
# 0    A     3   ak
# 1    B     1   tx
# 2    C     4   fl
# 3    A     1   hi
# 4    B     5   mi
# 5    C     9   ak
# 6    A     2   ca
# 7    C     5   sd
# 8    B     6   nc

# %%
# When we don't specify the columns, pandas will try to apply the aggregation to all columns. See next cell for proof!
df.groupby('col1').agg('max')
# Out:
#       col2 col3
# col1
# A        3   hi
# B        6   tx
# C        9   sd

# %%
df.groupby('col1')[['col2', 'col3']].agg('max')
# Out:
#       col2 col3
# col1
# A        3   hi
# B        6   tx
# C        9   sd

# %% [markdown]
# ### Case Study: Name "Popularity"

# %% [markdown]
# In this exercise, let's find the name with sex "F" that has dropped most in popularity since its peak usage in California. We'll start by filtering `babynames` to only include names corresponding to sex "F".

# %%
f_babynames = babynames[babynames["Sex"]=="F"]
f_babynames
# Out:
#        State Sex  Year      Name  Count
# 0         CA   F  1910      Mary    295
# 1         CA   F  1910     Helen    239
# 2         CA   F  1910   Dorothy    220
# 3         CA   F  1910  Margaret    163
# 4         CA   F  1910   Frances    134
# ...      ...  ..   ...       ...    ...
# 246852    CA   F  2024  Zipporah      5
# 246853    CA   F  2024     Ziyah      5
# 246854    CA   F  2024     Zosia      5
# 246855    CA   F  2024   Zuleika      5
# 246856    CA   F  2024      Zyah      5
#
# [246857 rows x 5 columns]

# %% [markdown]
# To build our intuition on how to answer our research question, let's visualize the prevalence of the name "Jennifer" over time.

# %%
jenn_entries = f_babynames[f_babynames["Name"]=="Jennifer"]
jenn_entries
# Out:
#        State Sex  Year      Name  Count
# 13610     CA   F  1934  Jennifer      5
# 16325     CA   F  1938  Jennifer      5
# 16993     CA   F  1939  Jennifer      6
# 17533     CA   F  1940  Jennifer     13
# 18210     CA   F  1941  Jennifer     24
# ...      ...  ..   ...       ...    ...
# 228822    CA   F  2020  Jennifer    141
# 232602    CA   F  2021  Jennifer     91
# 236182    CA   F  2022  Jennifer    115
# 239981    CA   F  2023  Jennifer     88
# 243663    CA   F  2024  Jennifer     80
#
# [88 rows x 5 columns]

# %%
# We'll talk about how to generate plots in a later lecture
fig = px.line(jenn_entries, x="Year", y="Count")

fig.update_layout(font_size = 18,
                  autosize=False,
                  width=1000,
                  height=400)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f67dc62f-0fa6-43a5-861d-d70f6464c85a" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f67dc62f-0fa6-43a5-861d-d70f6464c85a")) {                    Plotly.newPlot(                        "f67dc62f-0fa6-43a5-861d-d70f6464c85a",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1934,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[5,5,6,13,24,22,30,80,99,147,163,159,233,247,284,350,384,412,441,509,635,739,706,871,1174,1256,1385,1516,1650,1919,1902,2908,3477,4695,5456,6065,5649,5673,5324,5569,5543,5295,5461,5612,5627,5813,5832,5521,4965,4307,4285,3875,3529,3610,3579,3382,3003,2940,2696,2529,2817,2561,2675,2265,2027,1987,1699,1485,1297,1144,1035,808,641,515,474,421,354,286,243,239,226,168,145,141,91,115,88,80],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555555 ...

# %% [markdown]
# We'll need a mathematical definition for the change in popularity of a name in California.
#
# Define the metric "Ratio to Peak" (RTP). We'll calculate this as the count of the name in 2022 (the most recent year for which we have data) divided by the largest count of this name in *any* year.
#
# A demo calculation for Jennifer:

# %%
# Construct a Series containing our Jennifer count data
jenn_counts_ser = jenn_entries["Count"]
jenn_counts_ser
# Out:
# 13610       5
# 16325       5
# 16993       6
# 17533      13
# 18210      24
#          ...
# 228822    141
# 232602     91
# 236182    115
# 239981     88
# 243663     80
# Name: Count, Length: 88, dtype: int64

# %%
# In the year with the highest Jennifer count, 6065 Jennifers were born
max_jenn = np.max(jenn_counts_ser)
# jenn_counts_ser.max() -> 6065

max_jenn
# Out:
# 6065

# %%
# Remember that we sorted f_babynames by "Year".
# This means that grabbing the final entry gives us the most recent count of Jennifers: 80
# In 2024, the most recent year for which we have data, 80 Jennifers were born
latest_jenn = jenn_counts_ser.iloc[-1]
print(latest_jenn)
# Out:
# 80

# %%
# Compute the RTP
latest_jenn / max_jenn
# Out:
# np.float64(0.013190436933223413)

# %% [markdown]
# We can also write a function that produces the `ratio_to_peak`for a given `Series`. This will allow us to use `.groupby` to speed up our computation for all names in the dataset.

# %%
def ratio_to_peak(series):
    """
    Compute the RTP for a Series containing the counts per year for a single name (year column sorted ascendingly).
    """
    # return series.iloc[-1] / np.max(series)
    return series.iloc[-1] / series.max()

# %%
# Then, find the RTP
ratio_to_peak(jenn_counts_ser)
# Out:
# np.float64(0.013190436933223413)

# %% [markdown]
# Now, let's use `.groupby` to compute the RTPs for *all* names in the dataset.
#
# You may see a warning message when running the cell below. As discussed in the lecture, `pandas` can't apply an aggregation function to non-numeric data (it doesn't make sense to divide "CA" by a number). We can select numerical columns of interest directly.

# %%
rtp_table = f_babynames.groupby("Name")[["Year", "Count"]].agg(ratio_to_peak)
rtp_table
# Out:
#          Year     Count
# Name
# Aadhini   1.0  1.000000
# Aadhira   1.0  0.500000
# Aadhya    1.0  0.820000
# Aadya     1.0  1.000000
# Aahana    1.0  0.307692
# ...       ...       ...
# Zyanya    1.0  0.400000
# Zyla      1.0  0.942857
# Zylah     1.0  0.800000
# Zyra      1.0  0.678571
# Zyrah     1.0  1.000000
#
# [14045 rows x 2 columns]

# %% [markdown]
# This is the `pandas` equivalent of `.group` from [Data 8](http://data8.org/datascience/_autosummary/datascience.tables.Table.group.html). If we wanted to achieve this same result using the `datascience` library, we would write:
#
# `f_babynames.group("Name", ratio_to_peak)`

# %% [markdown]
# ### Exercise
#
# Is there a row where `Year` is not equal to 1? Recall that `babynames` is sorted ascending by year.

# %%
f_babynames
# Out:
#        State Sex  Year      Name  Count
# 0         CA   F  1910      Mary    295
# 1         CA   F  1910     Helen    239
# 2         CA   F  1910   Dorothy    220
# 3         CA   F  1910  Margaret    163
# 4         CA   F  1910   Frances    134
# ...      ...  ..   ...       ...    ...
# 246852    CA   F  2024  Zipporah      5
# 246853    CA   F  2024     Ziyah      5
# 246854    CA   F  2024     Zosia      5
# 246855    CA   F  2024   Zuleika      5
# 246856    CA   F  2024      Zyah      5
#
# [246857 rows x 5 columns]

# %%
# Unique values in the Year column
rtp_table["Year"].unique()
# Out:
# array([1.])

# %% [markdown]
# A hint: If we randomly shuffle the dataset, we see values of `Year` other than 1.
# - The maximum year for each name is no longer guaranteed to be the last-appearing year for each name! So, the ratio is no longer 1.

# %%
# .sample() method randomly selects a specified number or fraction of rows from the DataFrame.
# frac=1: Specifies that 100% of the rows (the entire DataFrame) should be selected.
# replace=False: Ensures that the sampling is done without replacement, meaning each row is used only once.

f_babynames.sample(frac=1, replace=False).groupby("Name")[["Year", "Count"]].agg(ratio_to_peak)
# Out:
#              Year     Count
# Name
# Aadhini  1.000000  1.000000
# Aadhira  0.997527  0.600000
# Aadhya   1.000000  0.820000
# Aadya    0.993083  0.241379
# Aahana   0.999012  0.269231
# ...           ...       ...
# Zyanya   0.990613  0.466667
# Zyla     0.992095  0.142857
# Zylah    0.998024  0.700000
# Zyra     0.997036  0.285714
# Zyrah    0.998024  0.833333
#
# [14045 rows x 2 columns]

# %%
# Dropping the "Year" column
rtp_table = rtp_table.drop("Year", axis="columns")
rtp_table
# Out:
#             Count
# Name
# Aadhini  1.000000
# Aadhira  0.500000
# Aadhya   0.820000
# Aadya    1.000000
# Aahana   0.307692
# ...           ...
# Zyanya   0.400000
# Zyla     0.942857
# Zylah    0.800000
# Zyra     0.678571
# Zyrah    1.000000
#
# [14045 rows x 1 columns]

# %%
# Rename "Count" to "Count RTP" for clarity
rtp_table = rtp_table.rename(columns={"Count":"Count RTP"})
rtp_table
# Out:
#          Count RTP
# Name
# Aadhini   1.000000
# Aadhira   0.500000
# Aadhya    0.820000
# Aadya     1.000000
# Aahana    0.307692
# ...            ...
# Zyanya    0.400000
# Zyla      0.942857
# Zylah     0.800000
# Zyra      0.678571
# Zyrah     1.000000
#
# [14045 rows x 1 columns]

# %%
# What name has fallen the most in popularity?
rtp_table.sort_values("Count RTP", ascending=True)
# Out:
#          Count RTP
# Name
# Debra     0.001512
# Debbie    0.002817
# Susan     0.003050
# Tammy     0.003249
# Cheryl    0.003819
# ...            ...
# Aaira     1.000000
# Aahna     1.000000
# Aadya     1.000000
# Zyrah     1.000000
# Aadhini   1.000000
#
# [14045 rows x 1 columns]

# %% [markdown]
# We can visualize the decrease in the popularity of the name "Debra:"

# %%
# The * in the parameter is used for multiple names
def plot_name(*names):
    fig = px.line(f_babynames[f_babynames["Name"].isin(names)],
                  x="Year", y="Count", color="Name", # color = column name
                  title=f"Popularity for: {names}")
    fig.update_layout(font_size=18,
                  autosize=False,
                  width=1000,
                  height=400)
    return fig

plot_name("Debra")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6c96e513-50bf-4324-b8fe-05180a5ad6b9" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c96e513-50bf-4324-b8fe-05180a5ad6b9")) {                    Plotly.newPlot(                        "6c96e513-50bf-4324-b8fe-05180a5ad6b9",                        [{"hovertemplate":"Name=Debra\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Debra","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Debra","orientation":"v","showlegend":true,"x":[1940,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2012,2013,2016,2023],"xaxis":"x","y":[7,7,8,15,19,20,56,92,199,601,1510,2351,3295,3784,3969,3754,3317,2660,2291,2012,1648,1592,1430,1287,1153,958,818,748,647,547,463,318,242,236,159,151,151,164,130,141,97,114,97,95,93,64,78,69,71,51,62,41,34,28,28,12,14,16,10,13,14,10,7,12,13,12,13,6,7,6,8,5,6],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar": ...

# %%
# Find the 10 names that have decreased the most in popularity
top10 = rtp_table.sort_values("Count RTP").head(10).index
top10
# Out:
# Index(['Debra', 'Debbie', 'Susan', 'Tammy', 'Cheryl', 'Michele', 'Kathleen',
#        'Terri', 'Shannon', 'Tina'],
#       dtype='object', name='Name')

# %%
plot_name(*top10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="46316e4b-14d9-4223-b6df-ee8bb7cf3b59" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46316e4b-14d9-4223-b6df-ee8bb7cf3b59")) {                    Plotly.newPlot(                        "46316e4b-14d9-4223-b6df-ee8bb7cf3b59",                        [{"hovertemplate":"Name=Kathleen\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kathleen","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Kathleen","orientation":"v","showlegend":true,"x":[1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[24,20,35,33,46,65,60,69,67,61,91,113,86,96,122,102,100,95,97,90,107,79,120,107,139,150,161,181,228,258,346,452,745,895,1008,1180,1652,1999,2110,2348,2311,2417,2388,2232,2098,2012,2076,1908,1785,1595,1386,1478,1341,1282,1239,1100,1036,858,816,802,683,559,485,387,362,322,305,354,332,327,350,346,410,388,444,434,425,445,452,409,482,400,383,327,326,298,261,198,179,193,184,148,142,124,112,109,113,86,89,71,80,58,56,56,39,38,43,46,27,35,24,24,19,17,11],"yaxis":"y","type":"scatter"},{"hovertemplate":"Name=Susan\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Susan","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Susan","orientation":"v","showlegend":true,"x":[1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[6,8,8,10,16,17,15,20,22,21,19,15,22,26,32,29,43,25,37,63,47,63,74,101,118,138,183,271,433,630,796,1058,1380,1596,1991,2689,2831,3338,3180,3260,3346,3424,3753,3934,3900,3771,3632,3504,3123,3146,3133,2952,2839,2535,2007,1826,1644,1368,1232,1070,861,651,530,552,496,456,437,424,409,420,361,391,352,338,273,280,272,286,267,272,260,196,202,172,152,152,114,116,103,101,104,86,76,70,71,74,53,56,41,39,43,28,44,26,45,22,26,22,19,17,8,13,18,12],"yaxis":"y","type":"scatter"},{"hovertemplate":"Name=Tina\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tina","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Tina","orientation":"v","showlegend":true,"x":[1915,1916,1917,1918,1920,1921,1922,1924,1925,1927,1928,1929,1930,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015 ...

# %% [markdown]
# For fun, try plotting your name or your friends' names.

# %% [markdown]
# ### `groupby.size` and `groupby.count()`

# %%
df = pd.DataFrame({'letter':['A', 'A', 'B', 'C', 'C', 'C'],
                   'num':[1, 2, 3, 4, np.nan, 4],
                   'state':[np.nan, 'tx', 'fl', 'hi', np.nan, 'ak']})
df
# Out:
#   letter  num state
# 0      A  1.0   NaN
# 1      A  2.0    tx
# 2      B  3.0    fl
# 3      C  4.0    hi
# 4      C  NaN   NaN
# 5      C  4.0    ak

# %% [markdown]
# `groupby.size()` returns a `Series`, indexed by the `letter`s that we grouped by, with values denoting the number of rows in each group/sub-DataFrame. It does not care about missing (`NaN`) values.

# %%
df.groupby("letter").size()
# Out:
# letter
# A    2
# B    1
# C    3
# dtype: int64

# %% [markdown]
# You might recall `value_counts()` function we talked about last week. What's the difference?

# %%
df["letter"].value_counts()
# Out:
# letter
# C    3
# A    2
# B    1
# Name: count, dtype: int64

# %% [markdown]
# Turns out `value_counts()` does something similar to `groupby.size()`, except that it also sorts the values of the resulting `Series` in descending order.

# %% [markdown]
# `groupby.count()` returns a `DataFrame`, indexed by the `letter`s that we grouped by. Each column represents the number of non-missing values for that `letter`.

# %%
df.groupby("letter").count()
# Out:
#         num  state
# letter
# A         2      1
# B         1      1
# C         2      2

# %% [markdown]
# ## Filtering by Group
#
# Another common use for groups is to filter data:
#
# Usage: `groupby(___).filter(func)`
#
# `.filter()` applies `func` to each group's sub-DataFrame (`sf`).
# - `func` must return a scalar `True` or `False` for each `sf`.
# - If `func` returns `True` for a `sf`, then all rows belonging to the group are preserved.
# - If `func` returns `False` for a `sf`, then all rows belonging to that group are filtered out.
#
# For example, we can filter to the subframes of `df` with at least 2 rows:

# %%
df.groupby("letter").filter(lambda sf: len(sf) >= 2)
# Out:
#   letter  num state
# 0      A  1.0   NaN
# 1      A  2.0    tx
# 3      C  4.0    hi
# 4      C  NaN   NaN
# 5      C  4.0    ak

# %% [markdown]
# ### Exercise
#
# Which of the following returns all rows of `babynames` with names that appeared for the first time after 2010?

# %%
babynames.groupby("Name").filter(lambda sf: sf["Year"].min() > 2010)
# Out:
#        State Sex  Year     Name  Count
# 195282    CA   F  2011  Mileidy     15
# 195296    CA   F  2011   Solara     15
# 195386    CA   F  2011   Yorley     14
# 195721    CA   F  2011  Mileydi     11
# 195848    CA   F  2011   Kensie     10
# ...      ...  ..   ...      ...    ...
# 420402    CA   M  2024    Zekai      5
# 420403    CA   M  2024     Zexi      5
# 420405    CA   M  2024     Ziah      5
# 420406    CA   M  2024   Zohaan      5
# 420408    CA   M  2024     Zuko      5
#
# [9803 rows x 5 columns]

# %%
babynames.groupby("Name").filter(lambda sf: sf["Year"].max() > 2010)
# Out:
#        State Sex  Year      Name  Count
# 0         CA   F  1910      Mary    295
# 1         CA   F  1910     Helen    239
# 2         CA   F  1910   Dorothy    220
# 3         CA   F  1910  Margaret    163
# 4         CA   F  1910   Frances    134
# ...      ...  ..   ...       ...    ...
# 420404    CA   M  2024      Ziad      5
# 420405    CA   M  2024      Ziah      5
# 420406    CA   M  2024    Zohaan      5
# 420407    CA   M  2024    Zubair      5
# 420408    CA   M  2024      Zuko      5
#
# [353229 rows x 5 columns]

# %%
babynames.groupby("Name").filter(lambda sf: sf["Year"] > 2010)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3979472272.py in <cell line: 0>()
# ----> 1 babynames.groupby("Name").filter(lambda sf: sf["Year"] > 2010)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/generic.py in filter(self, func, dropna, *args, **kwargs)
#    1930             else:
#    1931                 # non scalars aren't allowed
# -> 1932                 raise TypeError(
#    1933                     f"filter function returned a {type(res).__name__}, "
#    1934                     "but expected a scalar bool"
#
# TypeError: filter function returned a Series, but expected a scalar bool

# %%
babynames.groupby(["Name", "Year"]).filter(lambda sf: sf["Year"] > 2010)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1089417567.py in <cell line: 0>()
# ----> 1 babynames.groupby(["Name", "Year"]).filter(lambda sf: sf["Year"] > 2010)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/generic.py in filter(self, func, dropna, *args, **kwargs)
#    1930             else:
#    1931                 # non scalars aren't allowed
# -> 1932                 raise TypeError(
#    1933                     f"filter function returned a {type(res).__name__}, "
#    1934                     "but expected a scalar bool"
#
# TypeError: filter function returned a Series, but expected a scalar bool

# %% [markdown]
# ---------------

# %%
# Let's read the elections dataset
elections = pd.read_csv("/content/drive/MyDrive/Classroom/Data Science/elections.csv")
elections.sample(5)
# Out:
#      Year       Candidate        Party  Popular vote Result          %
# 36   1880  James Garfield   Republican       4453337    win  48.369234
# 150  1996      Ross Perot       Reform       8085294   loss   8.408844
# 42   1888  Alson Streeter  Union Labor        146602   loss   1.288861
# 95   1940   Norman Thomas    Socialist        116599   loss   0.234237
# 92   1936   Norman Thomas    Socialist        187910   loss   0.412876

# %% [markdown]
# Let's keep only the elections years where the maximum vote share `%` is less than 45%.

# %%
elections.groupby("Year").filter(lambda sf: sf["%"].max() < 45).head(10)
# Out:
#      Year             Candidate                 Party  Popular vote Result  \
# 23   1860       Abraham Lincoln            Republican       1855993    win
# 24   1860             John Bell  Constitutional Union        590901   loss
# 25   1860  John C. Breckinridge   Southern Democratic        848019   loss
# 26   1860    Stephen A. Douglas   Northern Democratic       1380202   loss
# 66   1912        Eugene V. Debs             Socialist        901551   loss
# 67   1912      Eugene W. Chafin           Prohibition        208156   loss
# 68   1912    Theodore Roosevelt           Progressive       4122721   loss
# 69   1912          William Taft            Republican       3486242   loss
# 70   1912        Woodrow Wilson            Democratic       6296284    win
# 115  1968        George Wallace  American Independent       9901118   loss
#
#              %
# 23   39.699408
# 24   12.639283
# 25   18.138998
# 26   29.522311
# 66    6.004354
# 67    1.386325
# 68   27.457433
# 69   23.218466
# 70   41.933422
# 115  13.571218

# %%
# Why did we get a DataFrame instead of a Series?
# Notice that "%" is in its own sublist!
elections_max_percentage = elections.groupby("Year")[["%"]].agg("max")
elections_max_percentage
# Out:
#               %
# Year
# 1824  57.210122
# 1828  56.203927
# 1832  54.574789
# 1836  52.272472
# 1840  53.051213
# 1844  50.749477
# 1848  47.309296
# 1852  51.013168
# 1856  45.306080
# 1860  39.699408
# 1864  54.951512
# 1868  52.665305
# 1872  55.928594
# 1876  51.528376
# 1880  48.369234
# 1884  48.884933
# 1888  48.656799
# 1892  46.121393
# 1896  51.213817
# 1900  52.342640
# 1904  56.562787
# 1908  52.013300
# 1912  41.933422
# 1916  49.367987
# 1920  60.574501
# 1924  54.329113
# 1928  58.368524
# 1932  57.672125
# 1936  60.978107
# 1940  54.871202
# 1944  53.773801
# 1948  49.601536
# 1952  55.325173
# 1956  57.650654
# 1960  50.082561
# 1964  61.344703
# 1968  43.565246
# 1972  60.907806
# 1976  50.271900
# 1980  50.897944
# 1984  59.023326
# 1988  53.518845
# 1992  43.118485
# 1996  49.296938
# 2000  48.491813
# 2004  50.771824
# 2008  53.023510
# 2012  51.258484
# 2016  48.521539
# 2020  51.311515
# 2024  49.808629

# %%
elections_max_percentage.sort_values(by="%").head()
# Out:
#               %
# Year
# 1860  39.699408
# 1912  41.933422
# 1992  43.118485
# 1968  43.565246
# 1856  45.306080

# %% [markdown]
# ### `groupby` Puzzle
#
# Assume that we want to know the best election by each party.

# %% [markdown]
# #### Attempt #1

# %% [markdown]
# We have to be careful when using aggregation functions. For example, the code below might be misinterpreted to say that Woodrow Wilson successfully ran for election in 2020. Why is this happening?

# %%
elections.groupby("Party").agg("max").head(10)
# Out:
#                        Year           Candidate  Popular vote Result  \
# Party
# American               1976  Thomas J. Anderson        873053   loss
# American Independent   1976       Lester Maddox       9901118   loss
# Anti-Masonic           1832        William Wirt        100715   loss
# Anti-Monopoly          1884     Benjamin Butler        134294   loss
# Citizens               1980      Barry Commoner        233052   loss
# Communist              1932   William Z. Foster        103307   loss
# Constitution           2016    Michael Peroutka        203091   loss
# Constitutional Union   1860           John Bell        590901   loss
# Democratic             2024      Woodrow Wilson      81268924    win
# Democratic-Republican  1824   John Quincy Adams        151271    win
#
#                                %
# Party
# American               21.554001
# American Independent   13.571218
# Anti-Masonic            7.821583
# Anti-Monopoly           1.335838
# Citizens                0.270182
# Communist               0.261069
# Constitution            0.152398
# Constitutional Union   12.639283
# Democratic             61.344703
# Democratic-Republican  57.210122

# %% [markdown]
# It's generally a good idea to be explicit about which columns to aggregate!

# %% [markdown]
# #### Attempt #2

# %% [markdown]
# Next, we'll write code that properly returns _the best result by each party_. That is, each row should show the Year, Candidate, Popular Vote, Result, and % for the election in which that party saw its best results (rather than mixing them as in the example above). Here's what the first few rows of the correct output should look like:
#
# <img src="images/parties.png" alt="Image" width="600">

# %%
elections_sorted_by_percent = elections.sort_values("%", ascending=False)
elections_sorted_by_percent.head(8)
# Out:
#      Year           Candidate       Party  Popular vote Result          %
# 114  1964      Lyndon Johnson  Democratic      43127041    win  61.344703
# 91   1936  Franklin Roosevelt  Democratic      27752648    win  60.978107
# 120  1972       Richard Nixon  Republican      47168710    win  60.907806
# 79   1920      Warren Harding  Republican      16144093    win  60.574501
# 133  1984       Ronald Reagan  Republican      54455472    win  59.023326
# 84   1928      Herbert Hoover  Republican      21427123    win  58.368524
# 86   1932  Franklin Roosevelt  Democratic      22821277    win  57.672125
# 109  1956   Dwight Eisenhower  Republican      35579180    win  57.650654

# %%
elections_sorted_by_percent.groupby("Party").head(1)
# Out:
#      Year               Candidate                  Party  Popular vote Result  \
# 114  1964          Lyndon Johnson             Democratic      43127041    win
# 120  1972           Richard Nixon             Republican      47168710    win
# 0    1824          Andrew Jackson  Democratic-Republican        151271   loss
# 27   1864         Abraham Lincoln         National Union       2211317    win
# 11   1840  William Henry Harrison                   Whig       1275583    win
# 31   1872          Horace Greeley     Liberal Republican       2834761   loss
# 3    1828       John Quincy Adams    National Republican        500897   loss
# 26   1860      Stephen A. Douglas    Northern Democratic       1380202   loss
# 68   1912      Theodore Roosevelt            Progressive       4122721   loss
# 22   1856        Millard Fillmore               American        873053   loss
# 143  1992              Ross Perot            Independent      19743821   loss
# 25   1860    John C. Breckinridge    Southern Democratic        848019   loss
# 115  1968          George Wallace   American Independent       9901118   loss
# 24   1860               John Bell   Constitutional Union        590901   loss
# 15   1848        Martin Van Buren              Free Soil        291501   loss
# 48   1892         James B. Weaver               Populist       1041028   loss
# 150  1996              Ross Perot                 Reform       8085294   loss
# 6    1832            William Wirt           Anti-Masonic        100715   loss
# 66   1912          Eugene V. Debs              Socialist        901551   loss
# 35   1880         James B. Weaver              Greenback        308649   loss
# 175  2016            Gary Johnson            Libertarian       4489235   loss
# 155  2000             Ralph Nader                  Green       2882955   loss
# 103  1948          Strom Thurmond              Dixiecrat       1175930   loss
# 49   1892            John Bidwell            Prohibition        270879   loss
# 93   1936           William Lemke                  Union        892378   loss
# 38   1884         Benjamin Butler          Anti-Monopoly        134294   loss
# 42   1888          Alson Streeter            Union Labor        146602   loss
# 78   1920   Parley P. Christensen           Farmer–Labor        265398   loss
# 50   1896          John M. Palmer    National Democratic        134645   loss
# 186  2024            Chase Oliver      Libertarian Party        650130   loss
# 127  1980          Barry Commoner               Citizens        233052   loss
# 89   1932       William Z. Foster              Communist        103307   loss
# 136  1988           Lenora Fulani           New Alliance        217221   loss
# 147  1996         Howard Phillips              Taxpayers        184656   loss
# 110  1956      T. Coleman Andrews         States' Rights        107929   loss
# 164  2008           Chuck Baldwin           Constitution        199750   loss
# 148  1996            John Hagelin            Natural Law        113670   loss
#
#              %
# 114  61.344703
# 120  60.907806
# 0    57.210122
# 27   54.951512
# 11   53.051213
# 31   44.071406
# 3    43.796073
# 26   29.522311
# 68   27.457433
# 22   21.554001
# 143  18.956298
# 25   18.138998
# 115  13.571218
# 24   12.639283
# 15   10.138474
# 48    8.645038
# 150   8.408844
# 6     7.821583
# 66    6.004354
# 35    3.352344
# 175   3.307714
# 155   2.741176
# 103   2.412304
# 49    2.249468
# 93    1.960733
# 38    1.335838
# 42    1.288861
# 78    0.995804
# 50    0.969566
# 186   0.418895
# 127   0.270182
# 89    0.261069
# 136   0.237804
# 147   0.192045
# 110   0.174883
# 164   0.152398
# 148   0.118219

# %% [markdown]
# #### Alternative Solutions

# %% [markdown]
# You'll soon discover that with `Pandas` rich tool set, there's typically more than one way to get to the same answer. Each approach has different tradeoffs in terms of readability, performance, memory consumption, complexity, and more. It will take some experience for you to develop a sense of which approach is better for each problem, but you should, in general, try to think if you can at least envision a different solution to a given problem, especially if you find your current solution to be particularly convoluted or hard to read.
#
# Here are a couple of other ways of obtaining the same result (in each case, we only show the top part with `head()`). The first approach uses `groupby` but finds the location of the maximum value via the `idxmax()` method (look up its documentation!).  We then index and sort by `Party` to match the requested formatting:

# %%
elections.groupby("Party")["%"].idxmax()
# Out:
# Party
# American                  22
# American Independent     115
# Anti-Masonic               6
# Anti-Monopoly             38
# Citizens                 127
# Communist                 89
# Constitution             164
# Constitutional Union      24
# Democratic               114
# Democratic-Republican      0
# Dixiecrat                103
# Farmer–Labor              78
# Free Soil                 15
# Green                    155
# Greenback                 35
# Independent              143
# Liberal Republican        31
# Libertarian              175
# Libertarian Party        186
# National Democratic       50
# National Republican        3
# National Union            27
# Natural Law              148
# New Alliance             136
# Northern Democratic       26
# Populist                  48
# Progressive               68
# Prohibition               49
# Reform                   150
# Republican               120
# Socialist                 66
# Southern Democratic       25
# States' Rights           110
# Taxpayers                147
# Union                     93
# Union Labor               42
# Whig                      11
# Name: %, dtype: int64

# %%
# This is the computational part
best_per_party = elections.loc[elections.groupby("Party")["%"].idxmax()]

# This indexes by Party to match the formatting above
best_per_party.set_index('Party').sort_index().head()
# Out:
#                       Year         Candidate  Popular vote Result          %
# Party
# American              1856  Millard Fillmore        873053   loss  21.554001
# American Independent  1968    George Wallace       9901118   loss  13.571218
# Anti-Masonic          1832      William Wirt        100715   loss   7.821583
# Anti-Monopoly         1884   Benjamin Butler        134294   loss   1.335838
# Citizens              1980    Barry Commoner        233052   loss   0.270182

# %% [markdown]
# And this one doesn't even use `groupby`! This approach instead uses the `drop_duplicates` method to keep only the last occurrence of of each party after having sorted by "%", which is the best performance.  Again, the 2nd line is purely formatting:

# %%
best_per_party2 = elections.sort_values("%").drop_duplicates(["Party"], keep="last")
best_per_party2.set_index("Party").sort_index().head()  # Formatting
# Out:
#                       Year         Candidate  Popular vote Result          %
# Party
# American              1856  Millard Fillmore        873053   loss  21.554001
# American Independent  1968    George Wallace       9901118   loss  13.571218
# Anti-Masonic          1832      William Wirt        100715   loss   7.821583
# Anti-Monopoly         1884   Benjamin Butler        134294   loss   1.335838
# Citizens              1980    Barry Commoner        233052   loss   0.270182

# %% [markdown]
# *Challenge:* See if you can find yet another approach that still gives the same answer.

# %% [markdown]
# ### `DataFrameGroupBy` Objects

# %% [markdown]
# The result of `groupby` is not a `DataFrame` or a list of `DataFrame`s. It is instead a special type called a `DataFrameGroupBy`.

# %%
grouped_by_party = elections.groupby("Party")
type(grouped_by_party)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# `GroupBy` objects are structured like dictionaries. In fact, we can actually see the dictionaries with the following code:

# %%
grouped_by_party.groups
# Out:
# {'American': [22, 126], 'American Independent': [115, 119, 124], 'Anti-Masonic': [6], 'Anti-Monopoly': [38], 'Citizens': [127], 'Communist': [89], 'Constitution': [160, 164, 172], 'Constitutional Union': [24], 'Democratic': [2, 4, 8, 10, 13, 14, 17, 20, 28, 29, 34, 37, 39, 45, 47, 52, 55, 57, 64, 70, 74, 77, 81, 83, 86, 91, 94, 97, 100, 105, 108, 111, 114, 116, 118, 123, 129, 134, 137, 140, 144, 151, 158, 162, 168, 176, 178, 183], 'Democratic-Republican': [0, 1], 'Dixiecrat': [103], 'Farmer–Labor': [78], 'Free Soil': [15, 18], 'Green': [149, 155, 156, 165, 170, 177, 181, 184], 'Greenback': [35], 'Independent': [121, 130, 143, 161, 167, 174, 185], 'Liberal Republican': [31], 'Libertarian': [125, 128, 132, 138, 139, 146, 153, 159, 163, 169, 175, 180], 'Libertarian Party': [186], 'National Democratic': [50], 'National Republican': [3, 5], 'National Union': [27], 'Natural Law': [148], 'New Alliance': [136], 'Northern Democratic': [26], 'Populist': [48, 61, 141], 'Progressive': [68, 82, 101, 107], 'Prohibition': [41, 44, 49, 51, 54, 59, 63, 67, 73, 75, 99], 'Reform': [150, 154], 'Republican': [21, 23, 30, 32, 33, 36, 40, 43, 46, 53, 56, 60, 65, 69, 72, 79, 80, 84, 87, 90, 96, 98, 104, 106, 109, 112, 113, 117, 120, 122, 131, 133, 135, 142, 145, 152, 157, 166, 171, 173, 179, 182], 'Socialist': [58, 62, 66, 71, 76, 85, 88, 92, 95, 102], 'Southern Democratic': [25], 'States' Rights': [110], 'Taxpayers': [147], 'Union': [93], 'Union Labor': [42], 'Whig': [7, 9, 11, 12, 16, 19]}

# %% [markdown]
# The `key`s of the dictionary are the groups (in this case, `Party`), and the `value`s are the **indices** of rows belonging to that group. We can access a particular sub-`DataFrame` using `get_group`:

# %%
grouped_by_party.get_group("Socialist")
# Out:
#      Year        Candidate      Party  Popular vote Result         %
# 58   1904   Eugene V. Debs  Socialist        402810   loss  2.985897
# 62   1908   Eugene V. Debs  Socialist        420852   loss  2.850866
# 66   1912   Eugene V. Debs  Socialist        901551   loss  6.004354
# 71   1916  Allan L. Benson  Socialist        590524   loss  3.194193
# 76   1920   Eugene V. Debs  Socialist        913693   loss  3.428282
# 85   1928    Norman Thomas  Socialist        267478   loss  0.728623
# 88   1932    Norman Thomas  Socialist        884885   loss  2.236211
# 92   1936    Norman Thomas  Socialist        187910   loss  0.412876
# 95   1940    Norman Thomas  Socialist        116599   loss  0.234237
# 102  1948    Norman Thomas  Socialist        139569   loss  0.286312

# %% [markdown]
# ---

# %% [markdown]
# ## Pivot Tables

# %% [markdown]
# ### `Groupby` with multiple columns

# %% [markdown]
# We want to build a table showing the total number of babies born of each sex in each year. One way is to `groupby` using both columns of interest:

# %%
# babynames.groupby(["Year", "Sex"])[["Count"]].sum()
babynames.groupby(["Year", "Sex"])[["Count"]].agg("sum")
# Out:
#            Count
# Year Sex
# 1910 F      5950
#      M      3213
# 1911 F      6602
#      M      3381
# 1912 F      9804
# ...          ...
# 2022 M    188931
# 2023 F    164675
#      M    179637
# 2024 F    164782
#      M    179389
#
# [230 rows x 1 columns]

# %% [markdown]
# ### `pivot_table`

# %%
babynames.head()
# Out:
#   State Sex  Year      Name  Count
# 0    CA   F  1910      Mary    295
# 1    CA   F  1910     Helen    239
# 2    CA   F  1910   Dorothy    220
# 3    CA   F  1910  Margaret    163
# 4    CA   F  1910   Frances    134

# %%
babynames.pivot_table(
    index="Year",
    columns="Sex",
    values="Count",
    aggfunc="sum")
# Out:
# Sex        F       M
# Year
# 1910    5950    3213
# 1911    6602    3381
# 1912    9804    8142
# 1913   11860   10234
# 1914   13815   13110
# ...      ...     ...
# 2020  174112  189488
# 2021  174417  189248
# 2022  173613  188931
# 2023  164675  179637
# 2024  164782  179389
#
# [115 rows x 2 columns]

# %% [markdown]
# ### `pivot_table` with Multiple values

# %%
babynames.pivot_table(
    index="Year",
    columns="Sex",
    values=["Count", "Name"],
    aggfunc="max")
# Out:
#      Count          Name
# Sex      F     M       F        M
# Year
# 1910   295   237  Yvonne  William
# 1911   390   214   Zelma   Willis
# 1912   534   501  Yvonne  Woodrow
# 1913   584   614   Zelma   Yoshio
# 1914   773   769   Zelma   Yoshio
# ...    ...   ...     ...      ...
# 2020  2354  2633   Zyrah     Zyon
# 2021  2408  2622    Zyra    Zyrus
# 2022  2188  2617    Zyra     Zyon
# 2023  1975  2673    Zyra     Zyon
# 2024  1986  2716   Zyrah     Zyon
#
# [115 rows x 4 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## Join Tables
#
# What if we want to know the popularity of presidential candidates' first names in California in 2022? What can we do?

# %%
elections.head(10)
# Out:
#    Year               Candidate                  Party  Popular vote Result  \
# 0  1824          Andrew Jackson  Democratic-Republican        151271   loss
# 1  1824       John Quincy Adams  Democratic-Republican        113142    win
# 2  1828          Andrew Jackson             Democratic        642806    win
# 3  1828       John Quincy Adams    National Republican        500897   loss
# 4  1832          Andrew Jackson             Democratic        702735    win
# 5  1832              Henry Clay    National Republican        484205   loss
# 6  1832            William Wirt           Anti-Masonic        100715   loss
# 7  1836       Hugh Lawson White                   Whig        146109   loss
# 8  1836        Martin Van Buren             Democratic        763291    win
# 9  1836  William Henry Harrison                   Whig        550816   loss
#
#            %
# 0  57.210122
# 1  42.789878
# 2  56.203927
# 3  43.796073
# 4  54.574789
# 5  37.603628
# 6   7.821583
# 7  10.005985
# 8  52.272472
# 9  37.721543

# %%
babynames_2022 = babynames[babynames["Year"]==2022]
babynames_2022.head(10)
# Out:
#        State Sex  Year      Name  Count
# 235881    CA   F  2022    Olivia   2188
# 235882    CA   F  2022      Emma   2087
# 235883    CA   F  2022    Camila   2050
# 235884    CA   F  2022       Mia   1890
# 235885    CA   F  2022    Sophia   1773
# 235886    CA   F  2022  Isabella   1741
# 235887    CA   F  2022      Luna   1524
# 235888    CA   F  2022     Sofia   1312
# 235889    CA   F  2022    Amelia   1295
# 235890    CA   F  2022     Emily   1111

# %%
elections["First Name"] = elections["Candidate"].str.split(" ").str[0]
elections
# Out:
#      Year          Candidate                  Party  Popular vote Result  \
# 0    1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1    1824  John Quincy Adams  Democratic-Republican        113142    win
# 2    1828     Andrew Jackson             Democratic        642806    win
# 3    1828  John Quincy Adams    National Republican        500897   loss
# 4    1832     Andrew Jackson             Democratic        702735    win
# ..    ...                ...                    ...           ...    ...
# 182  2024       Donald Trump             Republican      77303568    win
# 183  2024      Kamala Harris             Democratic      75019230   loss
# 184  2024         Jill Stein                  Green        861155   loss
# 185  2024     Robert Kennedy            Independent        756383   loss
# 186  2024       Chase Oliver      Libertarian Party        650130   loss
#
#              % First Name
# 0    57.210122     Andrew
# 1    42.789878       John
# 2    56.203927     Andrew
# 3    43.796073       John
# 4    54.574789     Andrew
# ..         ...        ...
# 182  49.808629     Donald
# 183  48.336772     Kamala
# 184   0.554864       Jill
# 185   0.487357     Robert
# 186   0.418895      Chase
#
# [187 rows x 7 columns]

# %% [markdown]
# The join function is called `merge` in pandas. `join` in pandas does something slightly different—we won't talk about it in this class.

# %%
display(elections.head())
display(babynames_2022.head())

merged = pd.merge(left=elections, right=babynames_2022,
                  left_on="First Name", right_on="Name")
merged
# Out:
#    Year          Candidate                  Party  Popular vote Result  \
# 0  1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1  1824  John Quincy Adams  Democratic-Republican        113142    win
# 2  1828     Andrew Jackson             Democratic        642806    win
# 3  1828  John Quincy Adams    National Republican        500897   loss
# 4  1832     Andrew Jackson             Democratic        702735    win
#
#            % First Name
# 0  57.210122     Andrew
# 1  42.789878       John
# 2  56.203927     Andrew
# 3  43.796073       John
# 4  54.574789     Andrew
#        State Sex  Year    Name  Count
# 235881    CA   F  2022  Olivia   2188
# 235882    CA   F  2022    Emma   2087
# 235883    CA   F  2022  Camila   2050
# 235884    CA   F  2022     Mia   1890
# 235885    CA   F  2022  Sophia   1773
#      Year_x          Candidate                  Party  Popular vote Result  \
# 0      1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1      1824  John Quincy Adams  Democratic-Republican        113142    win
# 2      1828     Andrew Jackson             Democratic        642806    win
# 3      1828  John Quincy Adams    National Republican        500897   loss
# 4      1832     Andrew Jackson             Democratic        702735    win
# ..      ...                ...                    ...           ...    ...
# 153    2020     Howard Hawkins                  Green        405035   loss
# 154    2024       Donald Trump             Republican      77303568    win
# 155    2024     Robert Kennedy            Independent        756383   loss
# 156    2024       Chase Oliver      Libertarian Party        650130   loss
# 157    2024       Chase Oliver      Libertarian Party        650130   loss
#
#              % First Name State Sex  Year_y    Name  Count
# 0    57.210122     Andrew    CA   M    2022  Andrew    747
# 1    42.789878       John    CA   M    2022    John    496
# 2    56.203927     Andrew    CA   M    2022  Andrew    747
# 3    43.796073       John    CA   M    2022    John    496
# 4    54.574789     Andrew    CA   M    2022  Andrew    747
# ..         ...        ...   ...  ..     ...     ...    ...
# 153   0.255731     Howard    CA   M    2022  Howard     18
# 154  49.808629     Donald    CA   M    2022  Donald     33
# 155   0.487357     Robert    CA   M    2022  Robert    409
# 156   0.418895      Chase    CA   F    2022   Chase      6
# 157   0.418895      Chase    CA   M    2022   Chase    204
#
# [158 rows x 12 columns]

# %%
merged.sort_values("Count", ascending=False)
# Out:
#      Year_x          Candidate              Party  Popular vote Result  \
# 40     1888  Benjamin Harrison         Republican       5443633    win
# 36     1884    Benjamin Butler      Anti-Monopoly        134294   loss
# 42     1892  Benjamin Harrison         Republican       5176108   loss
# 33     1880    James B. Weaver          Greenback        308649   loss
# 21     1856     James Buchanan         Democratic       1835140    win
# ..      ...                ...                ...           ...    ...
# 65     1912     Woodrow Wilson         Democratic       6296284    win
# 156    2024       Chase Oliver  Libertarian Party        650130   loss
# 78     1928     Herbert Hoover         Republican      21427123    win
# 81     1932     Herbert Hoover         Republican      15761254   loss
# 145    2016     Darrell Castle       Constitution        203091   loss
#
#              % First Name State Sex  Year_y      Name  Count
# 40   47.858041   Benjamin    CA   M    2022  Benjamin   1533
# 36    1.335838   Benjamin    CA   M    2022  Benjamin   1533
# 42   42.984101   Benjamin    CA   M    2022  Benjamin   1533
# 33    3.352344      James    CA   M    2022     James   1097
# 21   45.306080      James    CA   M    2022     James   1097
# ..         ...        ...   ...  ..     ...       ...    ...
# 65   41.933422    Woodrow    CA   M    2022   Woodrow      6
# 156   0.418895      Chase    CA   F    2022     Chase      6
# 78   58.368524    Herbert    CA   M    2022   Herbert      5
# 81   39.830594    Herbert    CA   M    2022   Herbert      5
# 145   0.149640    Darrell    CA   M    2022   Darrell      5
#
# [158 rows x 12 columns]
